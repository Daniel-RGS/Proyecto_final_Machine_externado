# %% [markdown]
# # Colección de Datos - OSINT Conflicto Irán-Israel
#
# Este notebook sirve como demo para ejecutar los scripts de recolección individualmente. Las fuentes base no requieren credenciales: Wikimedia Pageviews, Wikipedia Revisions y RSS/Google News. GDELT, ACLED y FIRMS se tratan como opcionales y solo se usan si devuelven datos reales.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.abspath('')))

from scripts.collect_wikimedia import collect_wikimedia_data
from scripts.collect_wikipedia_revisions import collect_wikipedia_revisions
from scripts.collect_gdelt import collect_gdelt_data
from scripts.collect_rss import collect_rss_data
from scripts.build_dataset import build_dataset
