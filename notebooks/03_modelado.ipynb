# %% [markdown]
# # Modelado de Machine Learning
#
# Entrenamiento de modelos de clasificación para predecir si el día siguiente cae en el cuartil alto de presión pública observada (`target_high_escalation_next_day`). El `DummyClassifier` se mantiene solo como baseline de comparación, no como generador de datos.

# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd()))

from scripts.train_models import train_models

metadata = train_models()
metadata['best_model'], metadata['results']
